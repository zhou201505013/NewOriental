# %%
# 情感分析统计数据
import pandas as pd

# %%
sentiment = pd.read_csv('../data/sentiment.csv')
sentiment.head()
# Out:
#    Unnamed: 0                 time  \
# 0           0  2022-06-19 15:42:32
# 1           1  2022-06-19 15:42:32
# 2           2  2022-06-19 15:42:32
# 3           3  2022-06-19 16:42:32
# 4           4  2022-06-19 16:42:32
#
#                                              comment    source        date  \
# 0                          董宇辉：小时候不懂得朱自清的《背影》，长大后才懂得  bilibili  2022-06-19
# 1                               活了18年了，别说初恋，我连男朋友都没有  bilibili  2022-06-19
# 2  我的初恋就是我老公，谈了13年，结婚6个月，身边的人都觉得很不可思议，我们俩反而觉得挺正常的...  bilibili  2022-06-19
# 3            她现在看到你如此成熟稳重有立场，她一定很高兴曾经成为你的女朋友，你是她的骄傲。  bilibili  2022-06-19
# 4                                                 成长  bilibili  2022-06-19
#
#   sentiment_label  positive_probs  negative_probs
# 0        negative        0.192710        0.807290
# 1        negative        0.034080        0.965920
# 2        positive        0.862732        0.137268
# 3        positive        0.928367        0.071633
# ...

# %%
sentiment_grouped = sentiment.groupby(['source', 'sentiment_label'])
sentiment_grouped.count()
# Out:
#                           Unnamed: 0   time  comment   date  positive_probs  \
# source   sentiment_label
# bilibili negative                135    135      135    135             135
#          positive                141    141      141    141             141
# douyin   negative              35909  35909    35909  35909           35909
#          positive              39523  39523    39523  39523           39523
# toutiao  negative                555    555      555    555             555
#          positive                702    702      702    702             702
# weibo    negative               4280   4280     4280   4280            4280
#          positive               6222   6222     6222   6222            6222
#
#                           negative_probs
# source   sentiment_label
# bilibili negative                    135
#          positive                    141
# douyin   negative                  35909
#          positive                  39523
# ...
